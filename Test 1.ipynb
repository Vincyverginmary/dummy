# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
pip install google-api-python-client
# Out:
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached google_auth-2.32.0-py2.py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached google_api_core-2.19.1-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached protobuf-5.27.2-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# ...
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# ...

# %%
from googleapiclient.discovery import build

# %%
"AIzaSyB6F0I1VeTuDrWFTH1lRno9ofOitnZwUYU"
# Out:
# 'AIzaSyB6F0I1VeTuDrWFTH1lRno9ofOitnZwUYU'

# %%
#api key connection

def Api_connect():
    Api_Id="AIzaSyB6F0I1VeTuDrWFTH1lRno9ofOitnZwUYU"

    api_service_name="youtube"
    api_version="v3"

    
    youtube=build(api_service_name, api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %%
#get channels information
def get_channels_info(channel_id):
        request=youtube.channels().list(
                        part="snippet,ContentDetails,statistics",
                        id=channel_id
        )
        response=request.execute()

        for i in response['items']:
            data=dict(Channel_Name=i["snippet"]['title'],
                    Channel_Id=i["id"],
                    SubscriberCount=i['statistics']['subscriberCount'],
                    Views=i["statistics"]["videoCount"],
                    Total_videos=i["statistics"]["videoCount"],
                    Channel_Description=i["snippet"]["description"],
                    Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
        return data

# %%
channel_details=get_channels_info("UCLKUZXgKWgN7zWuEHrPeYKA")

# %%
channel_details
# Out:
# {'Channel_Name': "Clara's Kitchen",
#  'Channel_Id': 'UCLKUZXgKWgN7zWuEHrPeYKA',
#  'SubscriberCount': '3040',
#  'Views': '273',
#  'Total_videos': '273',
#  'Channel_Description': 'Hello நண்பர்களே 😍.. நான் கற்று கொண்ட சமையல உங்களுடன் பகிர்ந்து கொள்ளவும் ,நமது youtube பயணத்தில்  ஆரோக்கியமான உணவுகளும் ,எளிமையான,சுவையான உணவுகளும் இருக்கும் ..சின்ன சின்ன tips ,vlogs🎒,product review🎁, beauty tips,motivational tips,cooking information everything u can see in our channel ...cook together with your support 👍and love......❤️. \nஉங்கள் ஆதரவை தொடர்ந்து  கொடுங்கள் நண்பர்களே🥰🥰..\nEat healthy stay happy 😊😊',
#  'Playlist_Id': 'UULKUZXgKWgN7zWuEHrPeYKA'}

# %%
#get video ids
def get_videos_ids(channel_id):
     video_ids=[]
     response=youtube.channels().list(id=channel_id,
                                   part='contentDetails').execute()
     Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

     next_page_token=None

     while True:
          response1=youtube.playlistItems().list(
                                             part='snippet',
                                             playlistId=Playlist_Id,
                                             maxResults=50,
                                             pageToken=next_page_token).execute()
          for i in range(len(response1['items'])):
               video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
          next_page_token=response1.get('nextPageToken')

          if next_page_token is None:
               break
     return video_ids

# %%
video_ids=get_videos_ids('UCLKUZXgKWgN7zWuEHrPeYKA')

# %%
len(video_ids)
# Out:
# 273

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(channel_Name=item['snippet']['channelTitle'],
                    channel_Id=item['snippet']['channelId'],
                    video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item.get('tags'),
                    Thumbnail=item['snippet']['thumbnails'],
                    Description=item['snippet']['description'],
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Comments=item.get('commentCount'),
                    Views=item['statistics']['viewCount'],
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_Status=item['contentDetails']['caption'],
                    )
            video_data.append(data)
    return video_data

# %%
video_details=get_video_info(video_ids)

# %%
len(video_details)
# Out:
# 273

# %%
video_ids
# Out:
# ['OxpsGYC8fMc',
#  'yEx163eEccI',
#  'zeLlLbQQ8O4',
#  'iUESokcuGxQ',
#  'wTieGUlLNyY',
#  '2BmaePBlET8',
#  'wOQGMG94M30',
#  '-xMCbqDtTpc',
#  'Me_bIYla9Co',
#  'uq5v99erywY',
#  'fw7-TeSHZMw',
#  '1XgrtTx0Uj8',
#  'k_n1f2Mhg_s',
#  'shl61QvMAJk',
#  'yy4wqzUM33Q',
#  'k6PhRaptok4',
#  'c9JGjrea4ZY',
#  'eTlIdSzA1DA',
#  'BEGzGYkEzAw',
#  '4c65XOlVYQE',
#  'YnyZWrypREg',
#  'xAAaZqII6_8',
#  'KgWHiiBbxNk',
#  'X2oRS4XozHg',
#  'LEoKGJ2VYDc',
#  'H3OawMRRSRc',
#  'sERHRTqPbJw',
#  'cjqAb_EUSn0',
#  'c6OhMnEWIAQ',
#  '8AHA-hQ0yAI',
#  'ZvBcGUjKS4c',
#  'f-xM6oFao1g',
#  '9Ukyhwaojfk',
#  'OmfV0xkMJwk',
#  'OIaFkDLP5ds',
#  'SRyRgKmLx9w',
#  '6pRFqPN_hq8',
#  'xqVztvxCPcw',
#  '4fHL0hh7usw',
#  'FK4yOl1k8iY',
#  'AdvWc59Lt0o',
#  'WqVUzGd8tqY',
#  'lUXrVvvwR48',
#  'Jv6w5N1XAjU',
#  'obF2sdUtrbo',
#  '_RCo5ekX-kw',
#  'cRn1d6Wtjio',
#  'p456G4GXoL0',
#  'n58zBI65JzQ',
#  'tKNLGXHQIy8',
#  '7jdyZwEXL54',
#  'GhZgAiOEKvs',
#  '3MS8Iqescmk',
#  'o1hEcbtefTo',
#  'dOHro5ZJ_tE',
# ...

# %%
#Clara's Kitchen:'UCLKUZXgKWgN7zWuEHrPeYKA'
#TTS shalini:'UCxnYn-4eeOPqy7M0i5Or17w'
#Shalma:'UCfnvI92X9rB7o69Vt5StJag'

# %%
#get cooment information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                    part="snippet",
                    videoId=video_id,
                    maxResults=50
                )
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                
                Comment_data.append(data)
    except:
        pass
    return Comment_data

# %%
comment_details=get_comment_info(video_ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'UgzLAVRvcwa7Up9QpfF4AaABAg',
#   'video_Id': 'OxpsGYC8fMc',
#   'Comment_Text': '36த்...lk .Half a gooseberry  pickle super .arumayaana preparation sister 💐👌🏻👍😋🌷🌷🌷❤❤❤',
#   'Comment_Author': '@Indravenkatesanskitchen',
#   'Comment_Published': '2024-07-20T14:24:59Z'},
#  {'Comment_Id': 'UgzV5_PNzy3q5MRumYZ4AaABAg',
#   'video_Id': 'OxpsGYC8fMc',
#   'Comment_Text': 'Super yummy pickle..',
#   'Comment_Author': '@AsmaasKitchenVlogs',
#   'Comment_Published': '2024-07-20T10:05:02Z'},
#  {'Comment_Id': 'UgySi6yRuWfF0olahrZ4AaABAg',
#   'video_Id': 'OxpsGYC8fMc',
#   'Comment_Text': 'Healthy recipe',
#   'Comment_Author': '@emiratestamilfood7159',
#   'Comment_Published': '2024-07-20T09:12:53Z'},
#  {'Comment_Id': 'Ugy-g_3NbuLAUukQ4Ld4AaABAg',
#   'video_Id': 'OxpsGYC8fMc',
#   'Comment_Text': 'Super healthy  pickle',
#   'Comment_Author': '@kanchan_jha31',
#   'Comment_Published': '2024-07-20T09:02:14Z'},
#  {'Comment_Id': 'UgwShmMe9zO39KQgwOh4AaABAg',
# ...

# %%
#get_playlist_details

request=youtube.playlists().list(
        part='snippet,contentDetails',
        channelId="UCfnvI92X9rB7o69Vt5StJag",
        maxResults=50
)
response=request.execute()

# %%
response['items'][]
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'ovH38kTQ6KTkQ1o1YBMB8vbXnLo',
#  'pageInfo': {'totalResults': 6, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'y9TsE0fLkW1QGcN4mC-6ogsnrhg',
#    'id': 'PLrI8k0lxpcyu2KXFAl0UWarxmRy4L1M42',
#    'snippet': {'publishedAt': '2024-02-20T08:28:51Z',
#     'channelId': 'UCfnvI92X9rB7o69Vt5StJag',
#     'title': 'solo shalma',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9HvHpAMo_E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U9HvHpAMo_E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U9HvHpAMo_E/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/U9HvHpAMo_E/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...
